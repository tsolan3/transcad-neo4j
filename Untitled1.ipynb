# %%
from bokeh.plotting import figure, show, output_file
from bokeh.tile_providers import get_provider, Vendors

tile_provider = get_provider(Vendors.CARTODBPOSITRON)

pl = figure(x_range=(5000000, 6000000), y_range=(6000000, 7000000),
           x_axis_type="mercator", y_axis_type="mercator")

pl.add_tile(tile_provider)

show(pl)

# %%
# saratov_coords = [51.5563789, 45.9798167]

# coordinate_nodes = [(x, y) for x, y in G2.nodes(data=True) if y['type'] == 'coord']
# edges = G2.edges()

# print(len(coordinate_nodes))
# sample_coords = [[node[1]['latitude'], node[1]['longitude']] for node in coordinate_nodes]
# longitudes = [coord[1] for coord in sample_coords]
# latitudes = [coord[0] for coord in sample_coords]

# plt.plot(longitudes, latitudes, 'b.')
# # plt.figure(figsize=(100,100))


# # for edge in edges:
# #     node1_coords = [[y['longitude'], y['latitude']] for x, y in G2.nodes(data=True) if x == edge[0]][0]
# #     node2_coords = [[y['longitude'], y['latitude']] for x, y in G2.nodes(data=True) if x == edge[1]][0]
# #     longs = [node1_coords[0], node2_coords[0]]
# #     lats = [node1_coords[1], node2_coords[1]]
# #     plt.plot(longs, lats, 'b.-')

# mplleaflet.show()

# %%
# import pandas as pd
# from bokeh.models import BoxZoomTool
# from bokeh.plotting import figure, output_notebook, show
# output_notebook()

# from functools import partial
# from shapely.geometry import Point
# from shapely.ops import transform
# import pyproj

# pnt = transform(
#     partial(
#         pyproj.transform,
#         pyproj.Proj(init='EPSG:4326'),
#         pyproj.Proj(init='EPSG:3857')), Point(51.54056, 46.00861))

# print(pnt.x, pnt.y)

# NYC = x_range, y_range = ((5737469,5837469),(5781729,5881729))

# plot_width  = int(750)
# plot_height = int(plot_width//1.2)

# def base_plot(tools='pan,wheel_zoom,reset, zoom_out',plot_width=plot_width, plot_height=plot_height, **plot_args):
#     p = figure(tools=tools, plot_width=plot_width, plot_height=plot_height,
#         x_range=x_range, y_range=y_range, outline_line_color=None,
#         min_border=0, min_border_left=0, min_border_right=0,
#         min_border_top=0, min_border_bottom=0, **plot_args)

#     p.axis.visible = False
#     p.xgrid.grid_line_color = None
#     p.ygrid.grid_line_color = None

#     p.add_tools(BoxZoomTool(match_aspect=True))

#     return p

# options = dict(line_color=None, fill_color='blue', size=5)

# %%
# import csv

# nodes_json = get_nodes_from_db(G2)

# with open('nodes.csv', 'w') as csvfile:
#     filewriter = csv.writer(csvfile, delimiter=',',
#                             quotechar='|', quoting=csv.QUOTE_MINIMAL)
#     filewriter.writerow(['Longitude', 'Latitude', 'ID'])
#     for node in nodes_json:
#         filewriter.writerow([node['longitude'], node['latitude'], node['pk']])

# %%
# from bokeh.plotting import figure, show, output_file
# from bokeh.tile_providers import get_provider, Vendors
# from pyproj import Proj, transform

# tile_provider = get_provider(Vendors.CARTODBPOSITRON)

# pl = figure(x_range=(5000000, 6000000), y_range=(6000000, 7000000),
#            x_axis_type="mercator", y_axis_type="mercator")

# pl.add_tile(tile_provider)



# transform(Proj(init='epsg:4326'), Proj(init='epsg:3857'), -0.1285907, 51.50809)  # longitude first, latitude second.
# # output (meters east of 0, meters north of 0): (-14314.651244750548, 6711665.883938471)
# coordinate_nodes = [(x, y) for x, y in G2.nodes(data=True) if y['type'] == 'coord']
# node_lats = [y['latitude'] for x,y in coordinate_nodes]
# node_longs = [y['longitude'] for x,y in coordinate_nodes]

# source = ColumnDataSource(
#     data=dict(lat=node_lats,
#               lon=node_longs)
# )

# pl.circle(x="lon", y="lat", size=100000, fill_color="blue", fill_alpha=0.8, source=source)

# show(pl)
